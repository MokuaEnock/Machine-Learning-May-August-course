# %%
import pandas as pd

# %%
file_path = "./S&P_500.csv"

# %%
df = pd.read_csv(file_path)

# %%
len(df.columns)
# Out:
# 616

# %%
df
# Out:
#           3/31/2024    Unnamed: 1       3/30/2024    Unnamed: 3  \
# 0                ID  ID().weights              ID  ID().weights
# 1     AAI KN Equity             0   AAI KN Equity             0
# 2    ABCL KN Equity             0  ABCL KN Equity             0
# 3    ABSA KN Equity      4.684016  ABSA KN Equity      4.684016
# 4    ARML KN Equity             0  ARML KN Equity             0
# ..              ...           ...             ...           ...
# 296             NaN           NaN             NaN           NaN
# 297             NaN           NaN             NaN           NaN
# 298             NaN           NaN             NaN           NaN
# 299             NaN           NaN             NaN           NaN
# 300             NaN           NaN             NaN           NaN
#
#           3/29/2024    Unnamed: 5       3/28/2024    Unnamed: 7  \
# 0                ID  ID().weights              ID  ID().weights
# 1     AAI KN Equity             0   AAI KN Equity             0
# ...
